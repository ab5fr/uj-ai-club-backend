# %%
# set a to have the value of 5
a = None
### BEGIN SOLUTION



### END SOLUTION

# %%
# dont delete this cell for auto grading
### BEGIN HIDDEN TESTS

assert a == 5, "The variable a should be equal to 5"

### END HIDDEN TESTS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 ### BEGIN HIDDEN TESTS
# ----> 3 assert a == 5, "The variable a should be equal to 5"
#       5 ### END HIDDEN TESTS
#
# NameError: name 'a' is not defined

# %%
# set b to have the value of 10
b = None
### BEGIN SOLUTION



### END SOLUTION

# %%
# dont delete this cell for auto grading
### BEGIN HIDDEN TESTS

assert b == 10, "The variable b should be equal to 10"

### END HIDDEN TESTS
