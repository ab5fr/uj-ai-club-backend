# %%
# give a the value 8
a = None
### BEGIN SOLUTION
a = 8
### END SOLUTION

# %%
### BEGIN HIDDEN TESTS
assert a == 8, "変数aに8を代入してください"
### END HIDDEN TESTS

# %%
# give a the value 69
b = None
### BEGIN SOLUTION
b = 69
### END SOLUTION

# %%
### BEGIN HIDDEN TESTS
assert b == 69, "変数aに69を代入してください"
### END HIDDEN TESTS
